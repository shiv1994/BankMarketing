# %%
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder

from scipy.stats import poisson, kstest
import seaborn as sns

sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

# %%
df = pd.read_csv(os.getcwd() + '/bank-full.csv', delimiter=";")

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.head(n=10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# ...

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.hist(column='age')
df.hist(column='balance')
df.hist(column='campaign')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff290f700f0>]],
#       dtype=object)

# %%
columns = ['job', 'education', 'default', 'loan', 'housing', 'marital', 'y', 'poutcome', 'duration']

for col in columns:
    print("For feature -> " + col + ":")
    print(df[col].value_counts(normalize=True) * 100)
    print("\n")
# Out:
# For feature -> job:
# blue-collar      21.525735
# management       20.919688
# technician       16.803433
# admin.           11.437482
# services          9.188029
# retired           5.007631
# self-employed     3.492513
# entrepreneur      3.289023
# unemployed        2.882042
# housemaid         2.742695
# student           2.074716
# unknown           0.637013
# Name: job, dtype: float64
#
#
# For feature -> education:
# secondary    51.319369
# tertiary     29.419831
# primary      15.153392
# unknown       4.107407
# Name: education, dtype: float64
#
#
# For feature -> default:
# no     98.197341
# yes     1.802659
# Name: default, dtype: float64
#
#
# For feature -> loan:
# no     83.977351
# yes    16.022649
# Name: loan, dtype: float64
#
#
# For feature -> housing:
# yes    55.583818
# no     44.416182
# Name: housing, dtype: float64
#
#
# For feature -> marital:
# married     60.193316
# single      28.289576
# divorced    11.517109
# Name: marital, dtype: float64
#
#
# ...

# %%
camps = 0
for index, row in df.iterrows():
    camps += row['campaign']
print("Average "camps/df.shape[0])
# Out:
# 2.763840658246887

# %%
res = df.query('y == "yes"')

# %%
res.shape
# Out:
# (5289, 17)

# %%
avg_bal = 0
for index, row in res.iterrows():
    avg_bal += int(row['balance'])
print(avg_bal/res.shape[0])
# Out:
# 1804.2679145396105

# %%
res.hist(column='balance')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff2f83dc5c0>]],
#       dtype=object)

# %%
res.query('balance < 0')
# Out:
#        age          job   marital  education default  balance housing loan  \
# 891     53     services  divorced    primary      no     -291     yes  yes
# 1247    49     services   married  secondary      no       -8     yes   no
# 1462    43  blue-collar   married    primary      no     -192     yes   no
# 1767    32  blue-collar   married  secondary     yes       -1     yes   no
# 1850    28  blue-collar    single  secondary      no     -197     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 43704   29   management    single   tertiary      no      -27      no   no
# 43843   28  blue-collar    single  secondary      no      -46     yes   no
# 44469   35       admin.    single  secondary      no      -32      no  yes
# 44626   31     services    single  secondary      no     -205      no   no
# 44629   28  blue-collar    single  secondary      no      -46     yes   no
#
# ...

# %%
res.query('balance > 0 & balance <=500')
# Out:
#        age            job   marital  education default  balance housing loan  \
# 86      56         admin.   married  secondary      no       45      no   no
# 168     54         admin.   married   tertiary      no      184      no   no
# 457     37     technician   married  secondary      no        1     yes   no
# 512     55     unemployed  divorced  secondary      no      387     yes   no
# 624     30     technician   married  secondary      no      484     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 45182   34     technician   married  secondary      no      133      no   no
# 45190   32    blue-collar   married  secondary      no      136      no   no
# 45193   28  self-employed    single   tertiary      no      159      no   no
# 45196   25        student    single  secondary      no      358      no   no
# 45203   23        student    single   tertiary      no      113      no   no
#
# ...

# %%
res.query('balance > 500 & balance <=1000')
# Out:
#        age          job   marital  education default  balance housing loan  \
# 388     56   management   married   tertiary      no      830     yes  yes
# 390     60      retired  divorced  secondary      no      545     yes   no
# 474     34       admin.   married  secondary      no      869      no   no
# 1172    31   technician    single   tertiary      no      703     yes   no
# 1200    32  blue-collar    single    primary      no      611     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45200   38   technician   married  secondary      no      557     yes   no
# 45201   53   management   married   tertiary      no      583      no   no
# 45202   34       admin.    single  secondary      no      557      no   no
# 45205   25   technician    single  secondary      no      505      no  yes
# 45206   51   technician   married   tertiary      no      825      no   no
#
# ...

# %%
res.query('balance > 1000 & balance <=1500')
# Out:
#        age          job   marital  education default  balance housing loan  \
# 87      41   technician   married  secondary      no     1270     yes   no
# 2483    60  blue-collar   married    primary      no     1262     yes  yes
# 2507    36  blue-collar   married  secondary      no     1165     yes   no
# 2779    53   technician  divorced    primary      no     1443     yes   no
# 2870    48  blue-collar   married  secondary      no     1405     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45096   63      retired   married  secondary      no     1495      no   no
# 45119   47       admin.   married  secondary      no     1210      no   no
# 45177   36       admin.  divorced  secondary      no     1224     yes   no
# 45187   32     services    single  secondary      no     1168     yes   no
# 45195   68      retired   married  secondary      no     1146      no   no
#
# ...

# %%
res.query('balance > 1000')
# Out:
#        age         job   marital  education default  balance housing loan  \
# 83      59      admin.   married  secondary      no     2343     yes   no
# 87      41  technician   married  secondary      no     1270     yes   no
# 129     55    services   married  secondary      no     2476     yes   no
# 446     39  technician    single    unknown      no    45248     yes   no
# 569     28    services    single  secondary      no     5090     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 45195   68     retired   married  secondary      no     1146      no   no
# 45197   36  management    single  secondary      no     1511     yes   no
# 45204   73     retired   married  secondary      no     2850      no   no
# 45207   71     retired  divorced    primary      no     1729      no   no
# 45208   72     retired   married  secondary      no     5715      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
res.query('balance>0 & balance <1000')
# Out:
#        age         job   marital  education default  balance housing loan  \
# 86      56      admin.   married  secondary      no       45      no   no
# 168     54      admin.   married   tertiary      no      184      no   no
# 388     56  management   married   tertiary      no      830     yes  yes
# 390     60     retired  divorced  secondary      no      545     yes   no
# 457     37  technician   married  secondary      no        1     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 45201   53  management   married   tertiary      no      583      no   no
# 45202   34      admin.    single  secondary      no      557      no   no
# 45203   23     student    single   tertiary      no      113      no   no
# 45205   25  technician    single  secondary      no      505      no  yes
# 45206   51  technician   married   tertiary      no      825      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
res2 = df.query('y == "no"')

# %%
res2.query('balance > 1000')
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 34      51    management   married   tertiary      no    10635     yes   no
# 40      44      services  divorced  secondary      no     2586     yes   no
# 50      54   blue-collar   married  secondary      no     1291     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45184   63       retired   married  secondary      no     1495      no   no
# 45186   59       unknown   married    unknown      no     1500      no   no
# 45198   37    management   married   tertiary      no     1428      no   no
# 45199   34   blue-collar    single  secondary      no     1475     yes   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # New Section - KS Test

# %%
mu = 2.76
possion_dist = poisson.rvs(mu, size=4000)

# %%
ax = sns.distplot(data_poisson,
                  bins=20,
                  kde=False,
                  color='red',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]

# %%
kstest(possion_dist, df['campaign'], alternative='two-sided', mode='exact')
# Out:
# KstestResult(statistic=0.1771391364933313, pvalue=2.418574653463043e-101)
